# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a54127-lab/Natural-language-processing/blob/main/NLP_LAB_1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install NLP libraries
# !pip install nltk spacy

# %%
import nltk
import spacy

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
text = """
The government announced new environmental policies aimed at reducing
carbon emissions and promoting renewable energy across the country.
"""

# %%
text_lower = text.lower()
print("Lowercase text:")
print(text_lower)
# Out:
# Lowercase text:
#
# the government announced new environmental policies aimed at reducing
# carbon emissions and promoting renewable energy across the country.

# %%
word_count = len(text_lower.split())

print("Number of words in the text:")
print(word_count)
# Out:
# Number of words in the text:
# 18
